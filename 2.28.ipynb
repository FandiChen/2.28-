# %%
import pandas as pd

# %%
df4=pd.read_csv("https://raw.githubusercontent.com/FandiChen/assignment1/refs/heads/main/task%202.28")

# %%
# Select the first 7 rows
df4.head(7)
# Out:
#        Name  S1_Grade  S2_Grade  S3_Grade  S4_Grade
# 0      Anna       4.0       2.0       3.0       3.0
# 1       Ewa       3.5       2.0       4.0       2.0
# 2  Krystyna       2.0       3.0       3.0       3.0
# 3    Dorota       2.0       5.0       4.0       5.0
# 4     Wanda       3.5       3.5       4.0       3.5
# 5     Edyta       2.0       3.0       4.0       4.0
# 6  Elżbieta       4.0       3.0       5.0       3.0

# %%
# Select random 9 rows
df4.sample(9)
# Out:
#           Name  S1_Grade  S2_Grade  S3_Grade  S4_Grade
# 10   Agnieszka       4.0       4.0       3.0       4.0
# 14  Aleksander       3.0       4.0       5.0       4.0
# 21   Krzysztof       5.0       3.5       2.0       3.5
# 13   Sebastian       4.0       5.0       3.0       2.0
# 16      Alojzy       3.5       3.0       2.0       3.0
# 1          Ewa       3.5       2.0       4.0       2.0
# 15      Wojtek       4.0       3.5       3.5       3.5
# 18      Maciej       3.5       3.5       3.5       2.0
# 12      Bogdan       5.0       3.0       3.5       3.0

# %%
# Create a list of all df4 columns
columns_list=df4.columns

# %%
# Calculate the mean of the "S1_Grade" column
df4["S1_Grade"].mean()
# Out:
# 3.5681818181818183

# %%
# Calculate the median of the 'S4_Grade' column
df4["S4_Grade"].median()
# Out:
# 3.0

# %%
# Provide unique values for the 'S3_Grade' column
df4["S3_Grade"].unique()
# Out:
# array([3. , 4. , 5. , 2. , 4.5, 3.5])

# %%
# Provide descriptive statistics for all columns in df4
df4.describe()
# Out:
#         S1_Grade   S2_Grade   S3_Grade   S4_Grade
# count  22.000000  22.000000  22.000000  22.000000
# mean    3.568182   3.340909   3.704545   3.295455
# std     0.890364   0.730074   0.983907   0.796706
# min     2.000000   2.000000   2.000000   2.000000
# 25%     3.500000   3.000000   3.000000   3.000000
# 50%     3.750000   3.250000   3.750000   3.000000
# 75%     4.000000   3.500000   4.375000   3.500000
# max     5.000000   5.000000   5.000000   5.000000

# %%
# Drop the column 'S4_Grade'
df4=df4.drop(columns=["S4_Grade"])
df4.columns
# Out:
# Index(['Name', 'S1_Grade', 'S2_Grade', 'S3_Grade'], dtype='object')

# %%
# Create the 'Diff_S1-S2' that shows difference between S1 and S2
df4["Diff_S1-S2"]=df4["S1_Grade"]-df4["S2_Grade"]

# %%
# Create df5 data frame consisting of 'Name' and 'Diff_S1-S2'
df5=df4[["Name", "Diff_S1-S2"]]

# %%
# Save df5 to the file 'df5.csv'
df5.to_csv("df5.csv")
